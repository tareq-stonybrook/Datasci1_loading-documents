# %% [markdown]
# <a href="https://colab.research.google.com/github/tareq-stonybrook/Datasci1_loading-documents/blob/main/datasci_1_loading_CSV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import files
files_uploaded = files.upload()

diabetic=pd.read_csv('diabetic_data1.csv')
diabetic.head(10)
# Out:
#      <input type="file" id="files-7fd94987-b16b-4d7c-9ef9-ed56e40f23be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fd94987-b16b-4d7c-9ef9-ed56e40f23be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# To load data from Google Drive, you first need to mount your Drive. This will prompt you to authorize this notebook to access your Google Drive files. Follow the instructions to complete the authorization.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Once your Drive is mounted, you can load your data. Replace `'path/to/your/file.csv'` with the actual path to your CSV file on Google Drive. For example, if your file is in a folder named 'my_data' in your Drive, the path might be `'/content/drive/MyDrive/my_data/your_file.csv'`.

# %%
# Replace 'path/to/your/file.csv' with the actual path to your CSV file on Google Drive
file_path = '/content/drive/MyDrive/path/to/your/file.csv'

try:
    df = pd.read_csv(file_path)
    print("Data loaded successfully!")
    display(df.head())
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please check the path.")
except Exception as e:
    print(f"An error occurred while loading the data: {e}")
